# %% [markdown]
# # WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "Output_Data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 615

# %%
#Setup my dataframe
cities_df = pd.DataFrame(cities)
cities_df = cities_df.rename(columns={0:'City'})
cities_df.head()

#Setup where i'll be storing the data for the different columns
cloud = []
country = []
date = []
humid = []
lat = []
lng = []
temp = []
wind = []
name = []

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# %%
# Beginning part of the print log 
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

# Get weather data
# for each city in the 'cities', get the needed data
# and add that to the dataframe.
#for index, row in cities_df.iterrows():
#    city = row['City']
city_record = 1

for city in cities:    
    try:
        response = requests.get(query_url+ city).json()
        cloud.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humid.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp_max'])
        wind.append(response['wind']['speed'])
        name.append(response['name'])
        
        print(f'Processing record {city_record} for city named: {city}')
        print(f'{query_url}{city}')
        
        city_record += 1

    except (KeyError, IndexError):
        
#         cloud.append(False)
#         country.append(False)
#         date.append(False)
#         humid.append(False)
#         lat.append(False)
#         lng.append(False)
#         temp.append(False)
#         wind.append(False)
        print('Missing field/result....skipping.')
    except:
        print(f'Failed on {city}.')
    continue
    time.sleep(1)
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing record 1 for city named: havelock
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=havelock
# Processing record 2 for city named: longonjo
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=longonjo
# Processing record 3 for city named: victoria
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=victoria
# Processing record 4 for city named: nagato
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=nagato
# Missing field/result....skipping.
# Processing record 5 for city named: grants pass
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=grants pass
# Processing record 6 for city named: pevek
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=pevek
# Missing field/result....skipping.
# Processing record 7 for city named: chuy
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=chuy
# Processing record 8 for city named: barrow
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=barrow
# Processing record 9 for city named: gladstone
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=gladstone
# Processing record 10 for city named: mataura
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=mataura
# Processing record 11 for city named: qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=qaanaaq
# Processing record 12 for city named: rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=rikitea
# Missing field/result....skipping.
# Processing record 13 for city named: port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=port alfred
# Processing record 14 for city named: mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=mahebourg
# Processing record 15 for city named: vaini
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=vaini
# Processing record 16 for city named: hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=hermanus
# Processing record 17 for city named: bismarck
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=bismarck
# Processing record 18 for city named: ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=ushuaia
# Processing record 19 for city named: east london
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=east london
# Processing record 20 for city named: sabang
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=sabang
# Processing record 21 for city named: bluff
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=bluff
# Processing record 22 for city named: yeppoon
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=yeppoon
# Missing field/result....skipping.
# Processing record 23 for city named: nabire
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=nabire
# Processing record 24 for city named: carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=carnarvon
# Processing record 25 for city named: moerai
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=moerai
# Processing record 26 for city named: lorengau
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=lorengau
# Processing record 27 for city named: yaan
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=yaan
# Processing record 28 for city named: kodiak
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=kodiak
# Processing record 29 for city named: guasdualito
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=guasdualito
# Missing field/result....skipping.
# Processing record 30 for city named: bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=bredasdorp
# Missing field/result....skipping.
# Processing record 31 for city named: christchurch
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=christchurch
# Processing record 32 for city named: narsaq
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=narsaq
# Processing record 33 for city named: ambulu
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=ambulu
# Processing record 34 for city named: pacific grove
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=pacific grove
# Processing record 35 for city named: albany
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=albany
# Processing record 36 for city named: shimoda
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=shimoda
# Processing record 37 for city named: poum
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=poum
# Processing record 38 for city named: okoneshnikovo
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=okoneshnikovo
# Processing record 39 for city named: pisco
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=pisco
# Processing record 40 for city named: katherine
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=katherine
# Processing record 41 for city named: saint anthony
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=saint anthony
# Missing field/result....skipping.
# Processing record 42 for city named: souillac
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=souillac
# Processing record 43 for city named: kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=kapaa
# Processing record 44 for city named: port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=port elizabeth
# Processing record 45 for city named: puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=puerto ayora
# Processing record 46 for city named: ribeira grande
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=ribeira grande
# Processing record 47 for city named: kangaatsiaq
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=kangaatsiaq
# Processing record 48 for city named: russell
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=russell
# Processing record 49 for city named: fairbanks
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=fairbanks
# Processing record 50 for city named: yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=yellowknife
# Processing record 51 for city named: hilo
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=hilo
# Processing record 52 for city named: tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=tiksi
# Processing record 53 for city named: atuona
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=atuona
# Processing record 54 for city named: punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=punta arenas
# Processing record 55 for city named: avarua
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=avarua
# Processing record 56 for city named: leningradskiy
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=leningradskiy
# Processing record 57 for city named: gat
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=gat
# Processing record 58 for city named: general roca
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=general roca
# Missing field/result....skipping.
# Processing record 59 for city named: port lincoln
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=port lincoln
# Missing field/result....skipping.
# Processing record 60 for city named: sao felix do xingu
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=sao felix do xingu
# Processing record 61 for city named: norman wells
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=norman wells
# Missing field/result....skipping.
# Processing record 62 for city named: selma
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=selma
# Processing record 63 for city named: cape town
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=cape town
# Processing record 64 for city named: saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=saint-philippe
# Processing record 65 for city named: high rock
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=high rock
# Processing record 66 for city named: butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=butaritari
# Processing record 67 for city named: yuli
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=yuli
# Missing field/result....skipping.
# Processing record 68 for city named: atikokan
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=atikokan
# Processing record 69 for city named: tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=tuktoyaktuk
# Processing record 70 for city named: mapiripan
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=mapiripan
# Missing field/result....skipping.
# Processing record 71 for city named: cidreira
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=cidreira
# Processing record 72 for city named: rafaela
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=rafaela
# Processing record 73 for city named: thompson
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=thompson
# Processing record 74 for city named: saldanha
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=saldanha
# Processing record 75 for city named: lagoa
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=lagoa
# Processing record 76 for city named: namibe
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=namibe
# Processing record 77 for city named: dicamay
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=dicamay
# Processing record 78 for city named: preston
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=preston
# Processing record 79 for city named: conceicao do mato dentro
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=conceicao do mato dentro
# Processing record 80 for city named: castro
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=castro
# Processing record 81 for city named: tuatapere
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=tuatapere
# Processing record 82 for city named: mokrous
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=mokrous
# Processing record 83 for city named: ayaviri
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=ayaviri
# Processing record 84 for city named: dolores
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=dolores
# Processing record 85 for city named: praya
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=praya
# Processing record 86 for city named: tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=tasiilaq
# Missing field/result....skipping.
# Processing record 87 for city named: lavrentiya
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=lavrentiya
# Processing record 88 for city named: samarai
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=samarai
# Missing field/result....skipping.
# Processing record 89 for city named: jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=jamestown
# Processing record 90 for city named: hailin
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=hailin
# Processing record 91 for city named: magadi
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=magadi
# Processing record 92 for city named: khandyga
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=khandyga
# Processing record 93 for city named: lipari
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=lipari
# Processing record 94 for city named: coihaique
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=coihaique
# Processing record 95 for city named: merauke
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=merauke
# Processing record 96 for city named: klaksvik
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=klaksvik
# Processing record 97 for city named: nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=nikolskoye
# Processing record 98 for city named: mayor pablo lagerenza
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=mayor pablo lagerenza
# Processing record 99 for city named: breves
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=breves
# Processing record 100 for city named: batemans bay
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=batemans bay
# Processing record 101 for city named: adrar
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=adrar
# Processing record 102 for city named: sabzevar
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=sabzevar
# Processing record 103 for city named: ambilobe
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=ambilobe
# Processing record 104 for city named: arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=arraial do cabo
# Processing record 105 for city named: salvador
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=salvador
# Processing record 106 for city named: ranong
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=ranong
# Missing field/result....skipping.
# Processing record 107 for city named: talaya
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=talaya
# Processing record 108 for city named: faanui
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=faanui
# Missing field/result....skipping.
# Processing record 109 for city named: zhangjiakou
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=zhangjiakou
# Missing field/result....skipping.
# Missing field/result....skipping.
# Processing record 110 for city named: imbituba
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=imbituba
# Processing record 111 for city named: tura
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=tura
# Processing record 112 for city named: port hope
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=port hope
# Processing record 113 for city named: wahiawa
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=wahiawa
# Processing record 114 for city named: hobart
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=hobart
# Processing record 115 for city named: pandan
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=pandan
# Processing record 116 for city named: georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=georgetown
# Processing record 117 for city named: esmeralda
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=esmeralda
# Processing record 118 for city named: brigantine
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=brigantine
# Processing record 119 for city named: mao
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=mao
# Processing record 120 for city named: cayenne
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=cayenne
# Processing record 121 for city named: boende
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=boende
# Processing record 122 for city named: pionerskiy
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=pionerskiy
# Processing record 123 for city named: takoradi
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=takoradi
# Missing field/result....skipping.
# Processing record 124 for city named: bethel
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=bethel
# Processing record 125 for city named: polunochnoye
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=polunochnoye
# Processing record 126 for city named: port blair
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=port blair
# Processing record 127 for city named: gibara
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=gibara
# Processing record 128 for city named: kirakira
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=kirakira
# Processing record 129 for city named: khani
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=khani
# Processing record 130 for city named: bambous virieux
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=bambous virieux
# Processing record 131 for city named: new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=new norfolk
# Processing record 132 for city named: znamenskoye
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=znamenskoye
# Processing record 133 for city named: biak
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=biak
# Processing record 134 for city named: rucheng
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=rucheng
# Processing record 135 for city named: lompoc
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=lompoc
# Processing record 136 for city named: vao
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=vao
# Processing record 137 for city named: belaya gora
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=belaya gora
# Processing record 138 for city named: sal rei
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=sal rei
# Missing field/result....skipping.
# Missing field/result....skipping.
# Processing record 139 for city named: sola
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=sola
# Processing record 140 for city named: gidam
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=gidam
# Processing record 141 for city named: bath
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=bath
# Processing record 142 for city named: itarema
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=itarema
# Processing record 143 for city named: khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=khatanga
# Processing record 144 for city named: colchester
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=colchester
# Processing record 145 for city named: sangar
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=sangar
# Missing field/result....skipping.
# Missing field/result....skipping.
# Processing record 146 for city named: dharmavaram
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=dharmavaram
# Missing field/result....skipping.
# Processing record 147 for city named: aykhal
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=aykhal
# Processing record 148 for city named: bud
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=bud
# Processing record 149 for city named: hovd
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=hovd
# Processing record 150 for city named: dongsheng
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=dongsheng
# Processing record 151 for city named: nioro
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=nioro
# Processing record 152 for city named: buena vista
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=buena vista
# Processing record 153 for city named: longyearbyen
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=longyearbyen
# Missing field/result....skipping.
# Processing record 154 for city named: lethem
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=lethem
# Processing record 155 for city named: baracoa
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=baracoa
# Processing record 156 for city named: yelabuga
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=yelabuga
# Processing record 157 for city named: vanimo
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=vanimo
# Processing record 158 for city named: trairi
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=trairi
# Processing record 159 for city named: marsabit
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=marsabit
# Processing record 160 for city named: cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=cabo san lucas
# Processing record 161 for city named: kantang
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=kantang
# Processing record 162 for city named: vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=vila franca do campo
# Processing record 163 for city named: kamaishi
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=kamaishi
# Processing record 164 for city named: susanville
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=susanville
# Processing record 165 for city named: barra do garcas
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=barra do garcas
# Processing record 166 for city named: beyneu
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=beyneu
# Processing record 167 for city named: busselton
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=busselton
# Processing record 168 for city named: san andres
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=san andres
# Missing field/result....skipping.
# Processing record 169 for city named: kuhdasht
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=kuhdasht
# Processing record 170 for city named: ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=ilulissat
# Processing record 171 for city named: kampong cham
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=kampong cham
# Processing record 172 for city named: monrovia
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=monrovia
# Processing record 173 for city named: provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=provideniya
# Missing field/result....skipping.
# Processing record 174 for city named: sambava
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=sambava
# Processing record 175 for city named: berezovyy
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=berezovyy
# Processing record 176 for city named: laguna
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=laguna
# Processing record 177 for city named: yancheng
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=yancheng
# Missing field/result....skipping.
# Processing record 178 for city named: cherskiy
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=cherskiy
# Processing record 179 for city named: salalah
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=salalah
# Processing record 180 for city named: charters towers
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=charters towers
# Missing field/result....skipping.
# Processing record 181 for city named: sungaipenuh
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=sungaipenuh
# Processing record 182 for city named: constitucion
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=constitucion
# Processing record 183 for city named: isangel
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=isangel
# Processing record 184 for city named: tripoli
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=tripoli
# Processing record 185 for city named: champagnole
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=champagnole
# Processing record 186 for city named: alice springs
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=alice springs
# Processing record 187 for city named: fortuna
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=fortuna
# Processing record 188 for city named: husavik
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=husavik
# Missing field/result....skipping.
# Processing record 189 for city named: troitsko-pechorsk
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=troitsko-pechorsk
# Processing record 190 for city named: saint george
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=saint george
# Processing record 191 for city named: tessalit
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=tessalit
# Processing record 192 for city named: turukhansk
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=turukhansk
# Processing record 193 for city named: palmer
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=palmer
# Processing record 194 for city named: kailua
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=kailua
# Processing record 195 for city named: vaitape
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=vaitape
# Processing record 196 for city named: kita
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=kita
# Processing record 197 for city named: iki-burul
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=iki-burul
# Processing record 198 for city named: pleasanton
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=pleasanton
# Processing record 199 for city named: plastun
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=plastun
# Processing record 200 for city named: talcahuano
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=talcahuano
# Processing record 201 for city named: stephenville
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=stephenville
# Processing record 202 for city named: tabou
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=tabou
# Processing record 203 for city named: puerto penasco
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=puerto penasco
# Processing record 204 for city named: kloulklubed
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=kloulklubed
# Processing record 205 for city named: mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=mar del plata
# Processing record 206 for city named: codrington
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=codrington
# Processing record 207 for city named: rosetta
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=rosetta
# Processing record 208 for city named: dingle
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=dingle
# Processing record 209 for city named: upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=upernavik
# Processing record 210 for city named: noumea
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=noumea
# Processing record 211 for city named: katsuura
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=katsuura
# Processing record 212 for city named: jamame
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=jamame
# Processing record 213 for city named: le vauclin
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=le vauclin
# Processing record 214 for city named: emba
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=emba
# Processing record 215 for city named: wheeling
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=wheeling
# Processing record 216 for city named: binga
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=binga
# Processing record 217 for city named: luangwa
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=luangwa
# Processing record 218 for city named: pauini
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=pauini
# Processing record 219 for city named: strezhevoy
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=strezhevoy
# Processing record 220 for city named: kavaratti
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=kavaratti
# Processing record 221 for city named: acajutla
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=acajutla
# Processing record 222 for city named: talnakh
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=talnakh
# Processing record 223 for city named: darhan
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=darhan
# Processing record 224 for city named: dunda
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=dunda
# Processing record 225 for city named: kitaibaraki
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=kitaibaraki
# Processing record 226 for city named: atasu
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=atasu
# Processing record 227 for city named: ferme-neuve
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=ferme-neuve
# Processing record 228 for city named: tubuala
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=tubuala
# Processing record 229 for city named: saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=saskylakh
# Processing record 230 for city named: liuhe
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=liuhe
# Processing record 231 for city named: sopelana
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=sopelana
# Processing record 232 for city named: huanren
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=huanren
# Processing record 233 for city named: atar
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=atar
# Processing record 234 for city named: sinnamary
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=sinnamary

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# weather_dict= {
#     'City': name,
#     'Cloudiness': cloud,
#     'Date': date,
#     'Humidity': humid,
#     'Lat': lat,
#     'Lng': lng,
#     'Max_Temp': temp,
#     'Wind_Speed': wind    
# }

# %%
d1 = pd.Series(name, name='City')
d2 = pd.Series(cloud, name='Cloudiness')
d3 = pd.Series(date, name='Date')
d4 = pd.Series(humid, name='Humidity')
d5 = pd.Series(lat, name='Lat')
d6 = pd.Series(lng, name='Lng')
d7 = pd.Series(temp, name='Max_Temp')
d8 = pd.Series(wind, name='Wind_Speed')
               
data = pd.concat([d1,d2,d3,d4,d5,d6,d7,d8], axis=1)
data.head

# %%
# url = "http://api.openweathermap.org/data/2.5/weather?"
# units = "imperial"

# # Build partial query URL
# query_url = f"{url}appid={api_key}&units={units}&q="
# city = 'pevek'
# response = requests.get(query_url+ city).json()
# cloud = response['clouds']['all']
# country = response['sys']['country']
# date = response['dt']
# humid = response['main']['humidity']
# lat = response['coord']['lat']
# lng = response['coord']['lon']
# temp = response['main']['temp_max']
# wind = response['wind']['speed']
# name = response['name']

# cloud, country, date, humid, lat, lng, temp, wind, name

# %%
# Check the counts for your data values 
data.count()

# %%
#cities_df.to_csv(output_data_file)

# %%
# cities_df['Cloudiness'] = cloud
# cities_df['Country'] = country
# cities_df['Date'] = date
# cities_df['Humidity'] = humidity
# cities_df['Lat'] = lat
# cities_df['Lng'] = lng
# cities_df['Max_Temp'] = temp
# cities_df['Wind_Speed'] = wind

# cities_df.head()

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(data['Lat'], data['Max_Temp'], marker='d', s=5)
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("Latitude_and_Temperature.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(data['Lat'], data['Humidity'], marker='d', s=5)
plt.title("City Latitude vs. Humidty")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("Latitude_and_Humidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(data['Lat'], data['Cloudiness'], marker='d', s=5)
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("Latitude_and_Cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(data['Lat'], data['Wind_Speed'], marker='d', s=5)
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("Latitude_and_Wind.png")
plt.show()
