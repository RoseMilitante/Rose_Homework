# %% [markdown]
# # WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "Output_Data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 620

# %%
#Setup my dataframe
cities_df = pd.DataFrame(cities)
cities_df = cities_df.rename(columns={0:'City'})
cities_df.head()

#Setup where i'll be storing the data for the different columns
cloud = []
country = []
date = []
humid = []
lat = []
lng = []
temp = []
wind = []
name = []

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# %%
# Beginning part of the print log 
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

# Get weather data
# for each city in the 'cities', get the needed data
# and add that to the dataframe.
#for index, row in cities_df.iterrows():
#    city = row['City']
city_record = 1

for city in cities:    
    try:
        response = requests.get(query_url+ city).json()
        cloud.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humid.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp_max'])
        wind.append(response['wind']['speed'])
        name.append(response['name'])
        
        print(f'Processing record {city_record} for city named: {city}')
        print(f'{query_url}{city}')
        
        city_record += 1

    except (KeyError, IndexError):
        
#         cloud.append(False)
#         country.append(False)
#         date.append(False)
#         humid.append(False)
#         lat.append(False)
#         lng.append(False)
#         temp.append(False)
#         wind.append(False)
        print('Missing field/result....skipping.')
    except:
        print(f'Failed on {city}.')
    continue
    time.sleep(1)
# Out:
# Beginning Data Retrieval
# -------------------------------
# Missing field/result....skipping.
# Processing record 1 for city named: deori
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=deori
# Processing record 2 for city named: saint-augustin
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=saint-augustin
# Missing field/result....skipping.
# Processing record 3 for city named: ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=ushuaia
# Processing record 4 for city named: port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=port alfred
# Processing record 5 for city named: mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=mahebourg
# Processing record 6 for city named: bathsheba
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=bathsheba
# Processing record 7 for city named: atuona
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=atuona
# Processing record 8 for city named: ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=ilulissat
# Processing record 9 for city named: namatanai
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=namatanai
# Processing record 10 for city named: opuwo
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=opuwo
# Processing record 11 for city named: rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=rikitea
# Processing record 12 for city named: punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=punta arenas
# Processing record 13 for city named: hobart
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=hobart
# Processing record 14 for city named: dire dawa
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=dire dawa
# Missing field/result....skipping.
# Processing record 15 for city named: richards bay
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=richards bay
# Processing record 16 for city named: saint george
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=saint george
# Processing record 17 for city named: ribeira grande
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=ribeira grande
# Processing record 18 for city named: airai
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=airai
# Processing record 19 for city named: gushikawa
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=gushikawa
# Processing record 20 for city named: longyearbyen
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=longyearbyen
# Processing record 21 for city named: luderitz
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=luderitz
# Missing field/result....skipping.
# Processing record 22 for city named: nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=nanortalik
# Processing record 23 for city named: qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=qaanaaq
# Missing field/result....skipping.
# Processing record 24 for city named: kutum
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=kutum
# Processing record 25 for city named: cape town
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=cape town
# Processing record 26 for city named: busselton
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=busselton
# Processing record 27 for city named: azovskaya
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=azovskaya
# Processing record 28 for city named: buarcos
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=buarcos
# Processing record 29 for city named: kendari
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=kendari
# Processing record 30 for city named: moree
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=moree
# Processing record 31 for city named: mataura
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=mataura
# Processing record 32 for city named: mayo
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=mayo
# Processing record 33 for city named: hilo
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=hilo
# Processing record 34 for city named: souillac
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=souillac
# Processing record 35 for city named: uttaradit
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=uttaradit
# Processing record 36 for city named: pangnirtung
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=pangnirtung
# Missing field/result....skipping.
# Processing record 37 for city named: cherskiy
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=cherskiy
# Processing record 38 for city named: nakamura
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=nakamura
# Processing record 39 for city named: goderich
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=goderich
# Processing record 40 for city named: arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=arraial do cabo
# Processing record 41 for city named: gore
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=gore
# Missing field/result....skipping.
# Processing record 42 for city named: kruisfontein
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=kruisfontein
# Processing record 43 for city named: mocajuba
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=mocajuba
# Missing field/result....skipping.
# Processing record 44 for city named: caucaia
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=caucaia
# Processing record 45 for city named: lincoln
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=lincoln
# Processing record 46 for city named: carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=carnarvon
# Processing record 47 for city named: nasirabad
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=nasirabad
# Processing record 48 for city named: hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=hermanus
# Processing record 49 for city named: victoria
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=victoria
# Processing record 50 for city named: delano
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=delano
# Processing record 51 for city named: vila
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=vila
# Processing record 52 for city named: albany
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=albany
# Processing record 53 for city named: avarua
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=avarua
# Processing record 54 for city named: balabac
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=balabac
# Processing record 55 for city named: barrow
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=barrow
# Processing record 56 for city named: half moon bay
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=half moon bay
# Processing record 57 for city named: kahului
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=kahului
# Processing record 58 for city named: gillette
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=gillette
# Processing record 59 for city named: ketchikan
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=ketchikan
# Missing field/result....skipping.
# Processing record 60 for city named: bluff
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=bluff
# Processing record 61 for city named: mandalgovi
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=mandalgovi
# Processing record 62 for city named: thompson
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=thompson
# Processing record 63 for city named: masunga
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=masunga
# Processing record 64 for city named: kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=kapaa
# Missing field/result....skipping.
# Missing field/result....skipping.
# Missing field/result....skipping.
# Processing record 65 for city named: bandipur
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=bandipur
# Missing field/result....skipping.
# Processing record 66 for city named: saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=saint-philippe
# Processing record 67 for city named: honiara
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=honiara
# Processing record 68 for city named: kaitangata
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=kaitangata
# Processing record 69 for city named: mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=mar del plata
# Processing record 70 for city named: saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=saskylakh
# Processing record 71 for city named: chapais
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=chapais
# Processing record 72 for city named: butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=butaritari
# Missing field/result....skipping.
# Processing record 73 for city named: jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=jamestown
# Missing field/result....skipping.
# Processing record 74 for city named: nome
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=nome
# Processing record 75 for city named: vaini
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=vaini
# Processing record 76 for city named: ortakoy
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=ortakoy
# Processing record 77 for city named: rocha
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=rocha
# Processing record 78 for city named: clearlake
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=clearlake
# Processing record 79 for city named: talnakh
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=talnakh
# Processing record 80 for city named: komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=komsomolskiy
# Processing record 81 for city named: cocachacra
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=cocachacra
# Processing record 82 for city named: austin
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=austin
# Processing record 83 for city named: faanui
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=faanui
# Processing record 84 for city named: murgab
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=murgab
# Missing field/result....skipping.
# Processing record 85 for city named: puerto madryn
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=puerto madryn
# Processing record 86 for city named: chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=chokurdakh
# Processing record 87 for city named: aviles
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=aviles
# Processing record 88 for city named: hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=hithadhoo
# Processing record 89 for city named: constitucion
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=constitucion
# Processing record 90 for city named: new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=new norfolk
# Processing record 91 for city named: torbay
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=torbay
# Processing record 92 for city named: esperance
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=esperance
# Processing record 93 for city named: vardo
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=vardo
# Processing record 94 for city named: lebu
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=lebu
# Processing record 95 for city named: port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=port elizabeth
# Missing field/result....skipping.
# Processing record 96 for city named: havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=havre-saint-pierre
# Processing record 97 for city named: kaeo
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=kaeo
# Processing record 98 for city named: honningsvag
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=honningsvag
# Processing record 99 for city named: trinidad
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=trinidad
# Processing record 100 for city named: egvekinot
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=egvekinot
# Processing record 101 for city named: nouadhibou
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=nouadhibou
# Processing record 102 for city named: oshikango
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=oshikango
# Processing record 103 for city named: lowestoft
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=lowestoft
# Processing record 104 for city named: saldanha
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=saldanha
# Processing record 105 for city named: nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=nikolskoye
# Processing record 106 for city named: rawson
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=rawson
# Processing record 107 for city named: norman wells
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=norman wells
# Processing record 108 for city named: buala
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=buala
# Processing record 109 for city named: chany
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=chany
# Processing record 110 for city named: yaan
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=yaan
# Processing record 111 for city named: lavrentiya
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=lavrentiya
# Processing record 112 for city named: dikson
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=dikson
# Processing record 113 for city named: nuuk
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=nuuk
# Processing record 114 for city named: coquimbo
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=coquimbo
# Processing record 115 for city named: bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=bredasdorp
# Processing record 116 for city named: luis correia
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=luis correia
# Processing record 117 for city named: yulara
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=yulara
# Processing record 118 for city named: severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=severo-kurilsk
# Processing record 119 for city named: bowen
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=bowen
# Processing record 120 for city named: ponta do sol
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=ponta do sol
# Processing record 121 for city named: derzhavinsk
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=derzhavinsk
# Processing record 122 for city named: lillehammer
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=lillehammer
# Processing record 123 for city named: laiyang
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=laiyang
# Processing record 124 for city named: fairbanks
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=fairbanks
# Processing record 125 for city named: grindavik
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=grindavik
# Processing record 126 for city named: hamilton
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=hamilton
# Processing record 127 for city named: butiama
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=butiama
# Processing record 128 for city named: inhambane
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=inhambane
# Processing record 129 for city named: falmouth
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=falmouth
# Processing record 130 for city named: ahipara
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=ahipara
# Processing record 131 for city named: fortuna
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=fortuna
# Processing record 132 for city named: yerbogachen
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=yerbogachen
# Processing record 133 for city named: samarai
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=samarai
# Processing record 134 for city named: smolenka
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=smolenka
# Processing record 135 for city named: itarema
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=itarema
# Processing record 136 for city named: yara
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=yara
# Missing field/result....skipping.
# Processing record 137 for city named: ushibuka
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=ushibuka
# Processing record 138 for city named: vinkovci
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=vinkovci
# Processing record 139 for city named: los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=los llanos de aridane
# Processing record 140 for city named: oussouye
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=oussouye
# Processing record 141 for city named: sao lourenco do sul
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=sao lourenco do sul
# Processing record 142 for city named: bambous virieux
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=bambous virieux
# Processing record 143 for city named: gat
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=gat
# Processing record 144 for city named: longhua
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=longhua
# Processing record 145 for city named: meulaboh
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=meulaboh
# Processing record 146 for city named: eydhafushi
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=eydhafushi
# Processing record 147 for city named: hofn
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=hofn
# Processing record 148 for city named: san juan del rio
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=san juan del rio
# Processing record 149 for city named: linjiang
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=linjiang
# Processing record 150 for city named: tibati
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=tibati
# Processing record 151 for city named: east london
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=east london
# Processing record 152 for city named: beringovskiy
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=beringovskiy
# Processing record 153 for city named: vezirkopru
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=vezirkopru
# Processing record 154 for city named: miraflores
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=miraflores
# Missing field/result....skipping.
# Processing record 155 for city named: santa rosa
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=santa rosa
# Processing record 156 for city named: manthani
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=manthani
# Processing record 157 for city named: karaton
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=karaton
# Processing record 158 for city named: sur
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=sur
# Processing record 159 for city named: popondetta
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=popondetta
# Processing record 160 for city named: irtyshskiy
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=irtyshskiy
# Processing record 161 for city named: mount gambier
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=mount gambier
# Processing record 162 for city named: sorong
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=sorong
# Processing record 163 for city named: sainte-marie
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=sainte-marie
# Processing record 164 for city named: villa maria
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=villa maria
# Failed on pacific grove.
# Processing record 165 for city named: lubango
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=lubango
# Processing record 166 for city named: te anau
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=te anau
# Processing record 167 for city named: lata
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=lata
# Processing record 168 for city named: puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=puerto ayora
# Processing record 169 for city named: klaksvik
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=klaksvik
# Processing record 170 for city named: eureka
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=eureka
# Processing record 171 for city named: kavieng
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=kavieng
# Processing record 172 for city named: batemans bay
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=batemans bay
# Processing record 173 for city named: dali
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=dali
# Processing record 174 for city named: dharchula
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=dharchula
# Processing record 175 for city named: tortoli
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=tortoli
# Processing record 176 for city named: tual
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=tual
# Processing record 177 for city named: cerrito
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=cerrito
# Processing record 178 for city named: ewa beach
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=ewa beach
# Processing record 179 for city named: hanzhong
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=hanzhong
# Processing record 180 for city named: ballina
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=ballina
# Missing field/result....skipping.
# Processing record 181 for city named: sitka
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=sitka
# Missing field/result....skipping.
# Processing record 182 for city named: charleville-mezieres
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=charleville-mezieres
# Processing record 183 for city named: iranshahr
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=iranshahr
# Processing record 184 for city named: mehamn
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=mehamn
# Processing record 185 for city named: tautira
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=tautira
# Processing record 186 for city named: port harcourt
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=port harcourt
# Processing record 187 for city named: otjimbingwe
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=otjimbingwe
# Processing record 188 for city named: tuatapere
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=tuatapere
# Processing record 189 for city named: hami
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=hami
# Processing record 190 for city named: leningradskiy
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=leningradskiy
# Processing record 191 for city named: ojinaga
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=ojinaga
# Processing record 192 for city named: gisborne
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=gisborne
# Processing record 193 for city named: vitim
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=vitim
# Processing record 194 for city named: sola
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=sola
# Processing record 195 for city named: zhigalovo
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=zhigalovo
# Processing record 196 for city named: kotido
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=kotido
# Processing record 197 for city named: zhuhai
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=zhuhai
# Processing record 198 for city named: santa fe
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=santa fe
# Processing record 199 for city named: khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=khatanga
# Processing record 200 for city named: lapua
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=lapua
# Processing record 201 for city named: talmenka
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=talmenka
# Processing record 202 for city named: helong
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=helong
# Processing record 203 for city named: tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=tasiilaq
# Processing record 204 for city named: kipushi
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=kipushi
# Processing record 205 for city named: hadejia
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=hadejia
# Processing record 206 for city named: bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=bandarbeyla
# Processing record 207 for city named: saint-pierre
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=saint-pierre
# Processing record 208 for city named: paracuru
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=paracuru
# Processing record 209 for city named: zaranj
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=zaranj
# Processing record 210 for city named: koudougou
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=koudougou
# Processing record 211 for city named: ancud
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=ancud
# Processing record 212 for city named: iqaluit
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=iqaluit
# Processing record 213 for city named: libertador general san martin
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=libertador general san martin
# Processing record 214 for city named: najran
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=najran
# Processing record 215 for city named: cockburn town
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=cockburn town
# Processing record 216 for city named: biltine
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=biltine
# Processing record 217 for city named: chubbuck
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=chubbuck
# Processing record 218 for city named: castro
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=castro
# Missing field/result....skipping.
# Processing record 219 for city named: san clemente
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=san clemente
# Processing record 220 for city named: gamba
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=gamba
# Processing record 221 for city named: rockland
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=rockland
# Missing field/result....skipping.
# Processing record 222 for city named: hasaki
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=hasaki
# Processing record 223 for city named: zhigansk
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=zhigansk
# Processing record 224 for city named: broome
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=broome
# Processing record 225 for city named: tomatlan
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=tomatlan
# Processing record 226 for city named: srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=srednekolymsk
# Processing record 227 for city named: muros
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=muros
# Processing record 228 for city named: port hedland
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=port hedland
# Processing record 229 for city named: dingle
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=dingle
# Processing record 230 for city named: skegness
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=skegness
# Processing record 231 for city named: santa maria
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=santa maria
# Processing record 232 for city named: anshun
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=anshun
# Processing record 233 for city named: san patricio
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=san patricio
# Processing record 234 for city named: marau
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=marau
# Processing record 235 for city named: cairns
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=cairns
# Processing record 236 for city named: uchiza
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=uchiza
# Processing record 237 for city named: nakambala
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=nakambala
# Missing field/result....skipping.
# Processing record 238 for city named: nabire
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=nabire
# Processing record 239 for city named: elk
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=elk
# Processing record 240 for city named: san julian
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=san julian
# Processing record 241 for city named: chuy
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=chuy
# Missing field/result....skipping.
# Processing record 242 for city named: raudeberg
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=raudeberg
# Processing record 243 for city named: bethel
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=bethel
# Processing record 244 for city named: mahibadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=mahibadhoo
# Processing record 245 for city named: yantal
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=yantal
# Processing record 246 for city named: san cristobal
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=san cristobal
# Processing record 247 for city named: santa vitoria do palmar
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=santa vitoria do palmar
# Processing record 248 for city named: vila velha
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=vila velha
# Processing record 249 for city named: davidson
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=davidson
# Processing record 250 for city named: makow mazowiecki
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=makow mazowiecki
# Processing record 251 for city named: college
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=college
# Processing record 252 for city named: georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=georgetown
# Processing record 253 for city named: erzurum
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=erzurum
# Processing record 254 for city named: megion
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=megion
# Missing field/result....skipping.
# Processing record 255 for city named: provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=provideniya
# Processing record 256 for city named: veraval
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=veraval
# Processing record 257 for city named: campoverde
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=campoverde
# Processing record 258 for city named: wewak
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=wewak
# Processing record 259 for city named: nalut
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=nalut
# Missing field/result....skipping.
# Processing record 260 for city named: granard
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=granard
# Missing field/result....skipping.
# Processing record 261 for city named: luanda
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=luanda
# Missing field/result....skipping.
# Processing record 262 for city named: upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=upernavik
# Processing record 263 for city named: galle
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=galle
# Processing record 264 for city named: kindu
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=kindu
# Processing record 265 for city named: mantua
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=mantua
# Missing field/result....skipping.
# Processing record 266 for city named: abashiri
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=abashiri
# Processing record 267 for city named: fairview
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=fairview
# Processing record 268 for city named: greymouth
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=greymouth
# Processing record 269 for city named: pisco
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=pisco
# Processing record 270 for city named: walvis bay
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=walvis bay
# Processing record 271 for city named: husavik
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=husavik
# Processing record 272 for city named: tezu
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=tezu
# Processing record 273 for city named: berdigestyakh
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=berdigestyakh
# Processing record 274 for city named: haines junction
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=haines junction
# Processing record 275 for city named: laem sing
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=laem sing
# Processing record 276 for city named: deputatskiy
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=deputatskiy
# Processing record 277 for city named: henties bay
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=henties bay
# Processing record 278 for city named: tahe
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=tahe
# Processing record 279 for city named: dunedin
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=dunedin
# Processing record 280 for city named: balakhninskiy
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=balakhninskiy
# Missing field/result....skipping.
# Processing record 281 for city named: awbari
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=awbari
# Processing record 282 for city named: chaumont
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=chaumont
# Processing record 283 for city named: lompoc
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=lompoc
# Processing record 284 for city named: porosozero
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=porosozero
# Processing record 285 for city named: port-gentil
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=port-gentil
# Missing field/result....skipping.
# Processing record 286 for city named: maragogi
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=maragogi
# Processing record 287 for city named: taltal
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=taltal
# Processing record 288 for city named: puerto del rosario
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=puerto del rosario
# Processing record 289 for city named: agirish
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=agirish
# Processing record 290 for city named: north bend
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=north bend
# Processing record 291 for city named: bantou
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=bantou
# Processing record 292 for city named: chitral
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=chitral
# Processing record 293 for city named: merauke
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=merauke
# Missing field/result....skipping.
# Processing record 294 for city named: ngunguru
# ...
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=bahar
# Processing record 460 for city named: yilan
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=yilan
# Processing record 461 for city named: palu
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=palu
# Processing record 462 for city named: mae hong son
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=mae hong son
# Processing record 463 for city named: ligaya
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=ligaya
# Processing record 464 for city named: vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=vila franca do campo
# Processing record 465 for city named: antofagasta
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=antofagasta
# Processing record 466 for city named: huarmey
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=huarmey
# Processing record 467 for city named: parrita
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=parrita
# Missing field/result....skipping.
# Processing record 468 for city named: lufilufi
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=lufilufi
# Processing record 469 for city named: ucluelet
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=ucluelet
# Processing record 470 for city named: toora-khem
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=toora-khem
# Processing record 471 for city named: ahome
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=ahome
# Processing record 472 for city named: salinas
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=salinas
# Processing record 473 for city named: molteno
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=molteno
# Processing record 474 for city named: brownwood
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=brownwood
# Processing record 475 for city named: ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=ugoofaaru
# Processing record 476 for city named: montepuez
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=montepuez
# Processing record 477 for city named: tateyama
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=tateyama
# Processing record 478 for city named: filadelfia
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=filadelfia
# Missing field/result....skipping.
# Processing record 479 for city named: kapit
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=kapit
# Processing record 480 for city named: valle hermoso
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=valle hermoso
# Processing record 481 for city named: wattegama
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=wattegama
# Processing record 482 for city named: alibunar
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=alibunar
# Processing record 483 for city named: nuevo progreso
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=nuevo progreso
# Processing record 484 for city named: garowe
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=garowe
# Processing record 485 for city named: hailar
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=hailar
# Processing record 486 for city named: araouane
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=araouane
# Missing field/result....skipping.
# Processing record 487 for city named: bilma
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=bilma
# Processing record 488 for city named: tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=tiksi
# Missing field/result....skipping.
# Processing record 489 for city named: vendas novas
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=vendas novas
# Processing record 490 for city named: makakilo city
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=makakilo city
# Processing record 491 for city named: barcelona
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=barcelona
# Processing record 492 for city named: ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=ostrovnoy
# Processing record 493 for city named: erzin
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=erzin
# Processing record 494 for city named: xuzhou
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=xuzhou
# Processing record 495 for city named: kloulklubed
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=kloulklubed
# Missing field/result....skipping.
# Missing field/result....skipping.
# Processing record 496 for city named: namibe
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=namibe
# Processing record 497 for city named: bafoulabe
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=bafoulabe
# Processing record 498 for city named: devrek
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=devrek
# Processing record 499 for city named: avera
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=avera
# Processing record 500 for city named: westport
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=westport
# Missing field/result....skipping.
# Processing record 501 for city named: clarence town
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=clarence town
# Missing field/result....skipping.
# Processing record 502 for city named: flin flon
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=flin flon
# Processing record 503 for city named: ginir
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=ginir
# Processing record 504 for city named: gannan
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=gannan
# Processing record 505 for city named: marsh harbour
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=marsh harbour
# Processing record 506 for city named: palana
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=palana
# Processing record 507 for city named: la rioja
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=la rioja
# Processing record 508 for city named: san ignacio
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=san ignacio
# Processing record 509 for city named: paamiut
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=paamiut
# Processing record 510 for city named: nambucca heads
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=nambucca heads
# Processing record 511 for city named: quatre cocos
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=quatre cocos
# Processing record 512 for city named: rabaul
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=rabaul
# Processing record 513 for city named: adrar
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=adrar
# Processing record 514 for city named: siuna
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=siuna
# Processing record 515 for city named: rio grande
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=rio grande
# Processing record 516 for city named: sayansk
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=sayansk
# Missing field/result....skipping.
# Processing record 517 for city named: kholodnyy
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=kholodnyy
# Processing record 518 for city named: shingu
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=shingu
# Processing record 519 for city named: zhangjiakou
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=zhangjiakou
# Processing record 520 for city named: boali
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=boali
# Processing record 521 for city named: chachapoyas
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=chachapoyas
# Processing record 522 for city named: kalyazin
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=kalyazin
# Processing record 523 for city named: tubuala
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=tubuala
# Processing record 524 for city named: rancagua
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=rancagua
# Processing record 525 for city named: banyo
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=banyo
# Processing record 526 for city named: saratoga springs
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=saratoga springs
# Processing record 527 for city named: robat karim
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=robat karim
# Processing record 528 for city named: hurricane
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=hurricane
# Missing field/result....skipping.
# Processing record 529 for city named: salalah
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=salalah
# Processing record 530 for city named: vostok
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=vostok
# Processing record 531 for city named: omboue
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=omboue
# Processing record 532 for city named: stulovo
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=stulovo
# Processing record 533 for city named: ilukste
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=ilukste
# Processing record 534 for city named: yuzhnyy
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=yuzhnyy
# Processing record 535 for city named: thinadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=thinadhoo
# Processing record 536 for city named: sistranda
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=sistranda
# Processing record 537 for city named: belyy yar
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=belyy yar
# Processing record 538 for city named: porto san giorgio
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=porto san giorgio
# Processing record 539 for city named: khasan
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=khasan
# Processing record 540 for city named: tabou
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=tabou
# Processing record 541 for city named: bridlington
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=bridlington
# Processing record 542 for city named: sampit
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=sampit
# Processing record 543 for city named: dawei
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=dawei
# Processing record 544 for city named: poum
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=poum
# Processing record 545 for city named: coahuayana
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=coahuayana
# Processing record 546 for city named: bonthe
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=bonthe
# Processing record 547 for city named: bemidji
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=bemidji
# Processing record 548 for city named: alofi
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=alofi
# Missing field/result....skipping.
# Processing record 549 for city named: nouakchott
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=nouakchott
# Processing record 550 for city named: batagay
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=batagay
# Processing record 551 for city named: makaha
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=makaha
# Processing record 552 for city named: karpathos
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=karpathos
# Processing record 553 for city named: labuhan
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=labuhan
# Processing record 554 for city named: crestview
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=crestview
# Processing record 555 for city named: guerrero negro
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=guerrero negro
# Processing record 556 for city named: portobelo
# http://api.openweathermap.org/data/2.5/weather?appid=cb630cd875dbadcfbb1abe55a670d55b&units=imperial&q=portobelo

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# weather_dict= {
#     'City': name,
#     'Cloudiness': cloud,
#     'Date': date,
#     'Humidity': humid,
#     'Lat': lat,
#     'Lng': lng,
#     'Max_Temp': temp,
#     'Wind_Speed': wind    
# }

# %%
d1 = pd.Series(name, name='City')
d2 = pd.Series(cloud, name='Cloudiness')
d3 = pd.Series(date, name='Date')
d4 = pd.Series(humid, name='Humidity')
d5 = pd.Series(lat, name='Lat')
d6 = pd.Series(lng, name='Lng')
d7 = pd.Series(temp, name='Max_Temp')
d8 = pd.Series(wind, name='Wind_Speed')
               
data = pd.concat([d1,d2,d3,d4,d5,d6,d7,d8], axis=1)
data.head
# Out:
# <bound method NDFrame.head of                   City  Cloudiness        Date  Humidity    Lat     Lng  \
# 0                Deori          89  1569892789        92  23.12   78.69
# 1       Saint-Augustin          90  1569892790        71  45.63  -73.98
# 2              Ushuaia          90  1569892508        86 -54.81  -68.31
# 3          Port Alfred          66  1569892792        85 -33.59   26.89
# 4            Mahebourg          40  1569892792        83 -20.41   57.70
# 5            Bathsheba          40  1569892793        78  13.22  -59.52
# 6               Atuona          15  1569892793        75  -9.80 -139.03
# 7            Ilulissat          89  1569892794        64  69.22  -51.10
# 8            Namatanai         100  1569892794        74  -3.66  152.44
# 9                Opuwo           0  1569892795        62 -18.06   13.84
# 10             Rikitea         100  1569892795        78 -23.12 -134.97
# 11        Punta Arenas          75  1569892796        69 -53.16  -70.91
# 12              Hobart          20  1569892502        47 -42.88  147.33
# 13           Dire Dawa          88  1569892796        80   9.59   41.86
# 14        Richards Bay         100  1569892797        69 -28.77   32.06
# 15        Saint George           0  1569892798        87  39.45   22.34
# 16      Ribeira Grande          97  1569892798        72  38.52  -28.70
# 17               Airai           0  1569892799        46  -8.93  125.41
# 18           Gushikawa          75  1569892799        79  26.35  127.87
# 19        Longyearbyen           0  1569892800        68  78.22   15.63
# 20            Luderitz           0  1569892515        52 -26.65   15.16
# 21          Nanortalik         100  1569892801        57  60.14  -45.24
# 22             Qaanaaq         100  1569892802        97  77.48  -69.36
# 23               Kutum          56  1569892803        58  14.20   24.66
# 24           Cape Town          20  1569892801        87 -33.93   18.42
# 25           Busselton          57  1569892803        73 -33.64  115.35
# 26           Azovskaya           0  1569892804       100  44.79   38.62
# 27             Buarcos          83  1569892804        92  40.16   -8.88
# 28             Kendari          77  1569892805        65  -3.99  122.52
# 29               Moree           0  1569892706        35 -29.46  149.84
# ..                 ...         ...         ...       ...    ...     ...
# 526        Robat Karim           0  1569893075        63  35.49   51.08
# 527          Hurricane           1  1569893076        11  37.18 -113.29
# 528            Salalah          40  1569893077        78  17.01   54.10
# 529             Vostok          56  1569893077        77  46.45  135.83
# 530             Omboue          68  1569893078        83  -1.57    9.26
# 531            Stulovo          75  1569893079        87  55.85   38.31
# 532            Ilukste         100  1569893079        93  55.98   26.30
# 533            Yuzhnyy         100  1569893079        87  53.54   39.45
# 534          Thinadhoo         100  1569893080        80   0.53   72.93
# 535          Sistranda          75  1569892926        93  63.73    8.83
# 536          Belyy Yar           0  1569893081        69  53.60   91.39
# 537  Porto San Giorgio           1  1569893081        72  43.18   13.79
# 538             Khasan           0  1569893081        66  42.43  130.64
# 539              Tabou          14  1569893082        97   4.42   -7.36
# 540        Bridlington         100  1569893082       100  54.08   -0.19
# 541             Sampit         100  1569893083        80  -2.54  112.95
# 542              Dawei          16  1569893083        83  14.07   98.19
# 543               Poum           0  1569893084        93  41.28   20.71
# 544         Coahuayana          95  1569893084        95  18.62 -100.35
# 545             Bonthe          29  1569893084        92   7.53  -12.50
# 546            Bemidji          90  1569892982        93  47.48  -94.89
# 547              Alofi          75  1569893086        88 -19.06 -169.92
# 548         Nouakchott           0  1569893087        83  18.08  -15.98
# 549            Batagay          81  1569893087        68  67.65  134.64
# 550             Makaha          75  1569893088        55  21.47 -158.22
# 551          Karpathos           0  1569893088        88  35.51   27.21
# 552            Labuhan         100  1569893088        63  -2.54  115.51
# 553          Crestview           1  1569893089        61  30.76  -86.57
# 554     Guerrero Negro           0  1569893090        74  27.97 -114.04
# 555          Portobelo          40  1569893090        94   9.55  -79.65
#
#      Max_Temp  Wind_Speed
# 0       72.36        5.66
# 1       53.60        4.70
# 2       33.80       16.11
# 3       57.99        5.01
# 4       72.00       10.29
# 5       82.40       11.41
# 6       79.70       15.75
# 7       35.60        1.12
# 8       81.25        7.87
# 9       52.43        1.83
# 10      68.88       14.29
# 11      35.60       12.75
# 12      59.00        6.93
# 13      64.54        3.24
# 14      65.79       20.04
# 15      66.20        2.30
# 16      70.61        9.60
# 17      83.30        1.97
# 18      86.00       14.99
# 19      28.40       13.87
# 20      64.40       11.41
# 21      42.84        9.24
# 22      34.12       13.04
# 23      77.50        2.82
# 24      59.00       12.75
# 25      63.00        3.00
# 26      55.99        4.47
# 27      68.00        7.05
# 28      83.23        0.78
# 29      77.00       16.11
# ..        ...         ...
# 526     66.20        9.17
# 527     72.00       10.29
# 528     80.60        4.70
# 529     60.66        5.06
# 530     75.97       13.76
# 531     57.20        8.95
# 532     53.10       13.13
# 533     54.77       19.91
# 534     81.88       16.28
# 535     37.99       10.29
# 536     35.60        6.71
# 537     68.00        4.70
# 538     67.75        2.13
# 539     74.93        3.11
# 540     53.60       11.41
# 541     78.08        2.86
# 542     79.74        4.72
# 543     48.20        3.36
# 544     71.92        1.90
# 545     76.89        5.14
# 546     51.80       10.29
# 547     78.80       10.29
# 548     78.80        5.82
# 549     24.71        2.37
# 550     87.80       20.80
# 551     69.80        5.82
# 552     79.99        0.72
# 553     84.20        4.16
# 554     67.60       22.70
# 555     75.20        3.36
#
# [556 rows x 8 columns]>

# %%
# url = "http://api.openweathermap.org/data/2.5/weather?"
# units = "imperial"

# # Build partial query URL
# query_url = f"{url}appid={api_key}&units={units}&q="
# city = 'pevek'
# response = requests.get(query_url+ city).json()
# cloud = response['clouds']['all']
# country = response['sys']['country']
# date = response['dt']
# humid = response['main']['humidity']
# lat = response['coord']['lat']
# lng = response['coord']['lon']
# temp = response['main']['temp_max']
# wind = response['wind']['speed']
# name = response['name']

# cloud, country, date, humid, lat, lng, temp, wind, name

# %%
# Check the counts for your data values 
data.count()
# Out:
# City          556
# Cloudiness    556
# Date          556
# Humidity      556
# Lat           556
# Lng           556
# Max_Temp      556
# Wind_Speed    556
# dtype: int64

# %%
#cities_df.to_csv(output_data_file)

# %%
# cities_df['Cloudiness'] = cloud
# cities_df['Country'] = country
# cities_df['Date'] = date
# cities_df['Humidity'] = humidity
# cities_df['Lat'] = lat
# cities_df['Lng'] = lng
# cities_df['Max_Temp'] = temp
# cities_df['Wind_Speed'] = wind

# cities_df.head()

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(data['Lat'], data['Max_Temp'], marker='d', s=5)
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("Latitude_and_Temperature.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(data['Lat'], data['Humidity'], marker='d', s=5)
plt.title("City Latitude vs. Humidty")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("Latitude_and_Humidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(data['Lat'], data['Cloudiness'], marker='d', s=5)
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("Latitude_and_Cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(data['Lat'], data['Wind_Speed'], marker='d', s=5)
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("Latitude_and_Wind.png")
plt.show()
